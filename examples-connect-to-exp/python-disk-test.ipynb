# %%
import gym_unbalanced_disk
import gymnasium
import numpy as np
from matplotlib import pyplot as plt

#create inputs
umax = 3.0 
np.random.seed(46)
ulist = np.random.uniform(-1,1,size=1000)
from scipy import signal
f0 = 0.8
ulist = signal.lfilter(*signal.butter(6,f0),ulist)
ulist /= max(np.max(ulist),-np.min(ulist))
ulist = umax*abs(ulist)**(1/4)*np.sign(ulist) #push to limits

plt.plot(ulist[:100])
plt.show()

env = gym_unbalanced_disk.UnbalancedDisk_exp(umax = umax,dt = 0.025)
obs, info = env.reset()
ylist = []
for u in ulist:
    ylist.append(obs)
    obs, reward, terminal, truncated, info = env.step(u)
env.reset()
# Out:
# ---------------------------------------------------------------------------
# NoBackendError                            Traceback (most recent call last)
# Cell In[1], line 19
#      16 plt.plot(ulist[:100])
#      17 plt.show()
# ---> 19 env = gym_unbalanced_disk.UnbalancedDisk_exp(umax = umax,dt = 0.025)
#      20 obs, info = env.reset()
#      21 ylist = []
#
# File d:\mihai\masters\y1\q4\mlsc\gym-unbalanced-disk\gym_unbalanced_disk\envs\UnbalancedDiskExp.py:38, in UnbalancedDisk_exp.__init__(self, umax, dt, force_restart_dev, inactivity_release_time, render_mode)
#      36     self.dev = dev
#      37 if not dev_active or force_restart_dev:
# ---> 38     self.init_dev()
#      40 assert isinstance(inactivity_release_time, int)
#      41 self.set_inactivity_release_time(inactivity_release_time)
#
# File d:\mihai\masters\y1\q4\mlsc\gym-unbalanced-disk\gym_unbalanced_disk\envs\UnbalancedDiskExp.py:78, in UnbalancedDisk_exp.init_dev(self)
#      76 except NameError:
#      77     pass
# ---> 78 dev = usb.core.find(idVendor=0x04b4, idProduct=0x8612)
#      79 dev.set_configuration() #this throws and error if python cannot connect to the disk.
#      80 self.dev = dev
#
# File c:\Users\aadmin\anaconda3\envs\cvq2_38\lib\site-packages\usb\core.py:1309, in find(find_all, backend, custom_match, **args)
#    1307             break
#    1308     else:
# -> 1309         raise NoBackendError('No backend available')
#    1311 if find_all:
#    1312     return device_iter(**args)
#
# NoBackendError: No backend available

# %%
plt.plot(ulist) 
plt.show()
plt.plot(ylist)
plt.show()

# %%
env.close()
